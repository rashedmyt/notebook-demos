% %%
syms a b
a = exp(b)
% Out:
% <math xmlns='http://www.w3.org/1998/Math/MathML' display='block' xmlns:mw='https://www.mathworks.com/MathML/extensions'>
%   <semantics>
%     <msup mw:template='exp' mw:dataCategory='structure'>
%       <mo mw:dataCategory='static'>&ee;</mo>
%       <mrow mw:dataCategory='placeholder'>
%         <mi>b</mi>
%       </mrow>
%     </msup>
%     <annotation encoding='OutputVersion'>
%       1.0
%     </annotation>
%     <annotation encoding='Suggestions'>
%       [{"entryType":"function","ID":"subs","text":"Substitute variables","description":"Substitute variables for values in expression or matrix: replace '0's and run code manually","code":"subs(a,[b],[0])","runOnInsert":false,"nargOut":1},{"entryType":"menu","ID":"menuCalculus","text":"Applying calculus functions","description":"Applying calculus functions","children":[{"entryType":"function","ID":"hessian","text":"Compute Hessian matrix","description":"Compute Hessian of scalar with respect to vector","code":"hessian(a)","runOnInsert":true,"nargOut":1},{"entryType":"function","ID":"taylor","text":"Compute Taylor expansion","description":"Compute Taylor polynomial expansion at specific point","code":"taylor(a,b)","runOnInsert":true,"nargOut":1},{"entryType":"function","ID":"gradient","text":"Compute gradient","description":"Compute gradient of scalar with respect to vector","code":"gradient(a)","runOnInsert":true,"nargOut":1},{"entryType":"function","ID":"limit","text":"Compute limit value","description":"Take the limit of symbolic expression at specific limit point","code":"limit(a,b,0)","runOnInsert":true,"nargOut":1},{"entryType":"function","ID":"poles","text":"Compute poles of function","description":"Compute poles of symbolic function","code":"poles(a,b)","runOnInsert":true,"nargOut":1},{"entryType":"function","ID":"series","text":"Compute series expansion","description":"Compute Puiseux series approximation at specific point","code":"series(a,b)","runOnInsert":true,"nargOut":1},{"entryType":"function","ID":"diff","text":"Differentiate function","description":"Compute derivative of function with respect to specific variable","code":"diff(a,b)","runOnInsert":true,"nargOut":1},{"entryType":"function","ID":"int","text":"Integrate function","description":"Compute indefinite integral of function with respect to specific variable","code":"int(a,b)","runOnInsert":true,"nargOut":1}]},{"entryType":"menu","ID":"menuTransform","text":"Computing integral transforms","description":"Computing integral transforms","children":[{"entryType":"function","ID":"fourier","text":"Compute Fourier transform","description":"Compute Fourier transform","code":"fourier(a)","runOnInsert":true,"nargOut":1},{"entryType":"function","ID":"htrans","text":"Compute Hilbert transform","description":"Compute Hilbert transform","code":"htrans(a)","runOnInsert":true,"nargOut":1},{"entryType":"function","ID":"laplace","text":"Compute Laplace transform","description":"Compute Laplace transform","code":"laplace(a)","runOnInsert":true,"nargOut":1},{"entryType":"function","ID":"ztrans","text":"Compute Z-transform","description":"Compute Z-transform","code":"ztrans(a)","runOnInsert":true,"nargOut":1},{"entryType":"separator","ID":"menuSeparator"},{"entryType":"function","ID":"ifourier","text":"Compute inverse Fourier transform","description":"Compute inverse Fourier transform","code":"ifourier(a)","runOnInsert":true,"nargOut":1},{"entryType":"function","ID":"ihtrans","text":"Compute inverse Hilbert transform","description":"Compute inverse Hilbert transform","code":"ihtrans(a)","runOnInsert":true,"nargOut":1},{"entryType":"function","ID":"ilaplace","text":"Compute inverse Laplace transform","description":"Compute inverse Laplace transform","code":"ilaplace(a)","runOnInsert":true,"nargOut":1},{"entryType":"function","ID":"iztrans","text":"Compute inverse Z-transform","description":"Compute inverse Z-transform","code":"iztrans(a)","runOnInsert":true,"nargOut":1}]},{"entryType":"menu","ID":"menuNumber","text":"Plotting functions","description":"Plotting functions, expressions, and equations","children":[{"entryType":"function","ID":"fplot","text":"Plot function","description":"Plot function f(x) or expression","code":"fplot(a)","runOnInsert":true,"nargOut":0},{"entryType":"function","ID":"fimplicit","text":"Plot implicit equation in 2-D","description":"Plot 2-D implicit equation or function f(x,y)","code":"fimplicit(a)","runOnInsert":true,"nargOut":0},{"entryType":"funct ...
%     </annotation>
%   </semantics>
% </math>

% %%
syms x1 x2 real
x = [x1;x2]; % column vector of symbolic variables
f = log(1 + 3*(x2 - (x1^3 - x1))^2 + (x1 - 4/3)^2)
% Out:
% <math xmlns='http://www.w3.org/1998/Math/MathML' display='block' xmlns:mw='https://www.mathworks.com/MathML/extensions'>
%   <semantics>
%     <mrow mw:template='apply' mw:dataCategory='structure'>
%       <mrow mw:dataCategory='placeholder'>
%         <mi>log</mi>
%       </mrow>
%       <mrow mw:dataCategory='structure-part'>
%         <mo form='prefix' mw:dataCategory='static'>(</mo>
%         <mrow>
%           <mrow mw:dataCategory='placeholder'>
%             <mrow mw:template='plus' mw:dataCategory='structure'>
%               <mrow mw:dataCategory='placeholder'>
%                 <msup mw:template='power' mw:dataCategory='structure'>
%                   <mfenced mw:dataCategory='structure-part'>
%                     <mrow mw:dataCategory='placeholder'>
%                       <mrow mw:template='plus' mw:dataCategory='structure'>
%                         <mrow mw:dataCategory='placeholder'>
%                           <msub mw:varname='x1'>
%                             <mi>x</mi>
%                             <mn>1</mn>
%                           </msub>
%                           <mo>-</mo>
%                           <mfrac mw:template='divide' mw:dataCategory='structure'>
%                             <mrow mw:dataCategory='placeholder'>
%                               <mn>4</mn>
%                             </mrow>
%                             <mrow mw:dataCategory='placeholder'>
%                               <mn>3</mn>
%                             </mrow>
%                           </mfrac>
%                         </mrow>
%                       </mrow>
%                     </mrow>
%                   </mfenced>
%                   <mrow mw:dataCategory='placeholder'>
%                     <mn>2</mn>
%                   </mrow>
%                 </msup>
%                 <mo>+</mo>
%                 <mrow mw:template='times' mw:dataCategory='structure'>
%                   <mrow mw:dataCategory='placeholder'>
%                     <mn>3</mn>
%                     <mo form='infix' mw:dataCategory='static'>&InvisibleTimes;</mo>
%                     <msup mw:template='power' mw:dataCategory='structure'>
%                       <mfenced mw:dataCategory='structure-part'>
%                         <mrow mw:dataCategory='placeholder'>
%                           <mrow mw:template='plus' mw:dataCategory='structure'>
%                             <mrow mw:dataCategory='placeholder'>
%                               <mo>-</mo>
%                               <msup mw:template='power' mw:dataCategory='structure'>
%                                 <mrow mw:dataCategory='placeholder'>
%                                   <msub mw:varname='x1'>
%                                     <mi>x</mi>
%                                     <mn>1</mn>
%                                   </msub>
%                                 </mrow>
%                                 <mrow mw:dataCategory='placeholder'>
%                                   <mn>3</mn>
%                                 </mrow>
%                               </msup>
%                               <mo>+</mo>
%                               <msub mw:varname='x1'>
%                                 <mi>x</mi>
%                                 <mn>1</mn>
%                               </msub>
%                               <mo>+</mo>
%                               <msub mw:varname='x2'>
%                                 <mi>x</mi>
%                                 <mn>2</mn>
%                               </msub>
%                             </mrow>
%                           </mrow>
%                         </mrow>
%                       </mfenced>
%                       <mrow mw:dataCategory='placeholder'>
%                         <mn>2</mn>
%                       </mrow>
%                     </msup>
%                   </mrow>
%                 </mrow>
%                 <mo>+</mo>
%                 <mn>1</mn>
%               </mrow>
%             </mrow>
%           </mrow>
%         </mrow>
%         <mo form='postfix' mw:dataCategory='static'>)</mo>
%       </mrow>
%     </mrow>
%     <annotation encoding='OutputVersion'>
%       1.0
%     </annotation>
%     <annotation encoding='Suggestions'>
%       [{"entryType":"function","ID":"vpa","text":"Approximate numerically","description":"Approximate numerically using variable precision floating point arithmetic","code":"vpa(f)","runOnInsert":true,"nargOut":1},{"entryType":"function","ID":"subs","text":"Substitute variables","description":"Substitute variables for values in expression or matrix: replace '0's and run code manually","code":"subs(f,[x1,x2],[0,0])","runOnInsert":false,"nargOut":1},{"entryType":"menu","ID":"menuCalculus","text":"Applying calculus functions","description":"Applying calculus functions","children":[{"entryType":"function","ID":"hessian","text":"Compute Hessian matrix","description":"Compute Hessian of scalar with respect to vector","code":"hessian(f)","runOnInsert":true,"nargOut":1},{"entryType":"function","ID":"taylor","text":"Compute Taylor expansion","description":"Compute Taylor polynomial expansion at specific point","code":"taylor(f,x1)","runOnInsert":true,"nargOut":1},{"entryType":"function","ID":"gradient","text":"Compute gradient","description":"Compute gradient of scalar with respect to vector","code":"gradient(f)","runOnInsert":true,"nargOut":1},{"entryType":"function","ID":"limit","text":"Compute limit value","description":"Take the limit of symbolic expression at specific limit point","code":"limit(f,x1,0)","runOnInsert":true,"nargOut":1},{"entryType":"function","ID":"poles","text":"Compute poles of function","description":"Compute poles of symbolic function","code":"poles(f,x1)","runOnInsert":true,"nargOut":1},{"entryType":"function","ID":"series","text":"Compute series expansion","description":"Compute Puiseux series approximation at specific point","code":"series(f,x1)","runOnInsert":true,"nargOut":1},{"entryType":"function","ID":"diff","text":"Differentiate function","description":"Compute derivative of function with respect to specific variable","code":"diff(f,x1)","runOnInsert":true,"nargOut":1},{"entryType":"function","ID":"int","text":"Integrate function","description":"Compute indefinite integral of function with respect to specific variable","code":"int(f,x1)","runOnInsert":true,"nargOut":1}]},{"entryType":"menu","ID":"menuTransform","text":"Computing integral transforms","description":"Computing integral transforms","children":[{"entryType":"function","ID":"fourier","text":"Compute Fourier transform","description":"Compute Fourier transform","code":"fourier(f)","runOnInsert":true,"nargOut":1},{"entryType":"function","ID":"htrans","text":"Compute Hilbert transform","description":"Compute Hilbert transform","code":"htrans(f)","runOnInsert":true,"nargOut":1},{"entryType":"function","ID":"laplace","text":"Compute Laplace transform","description":"Compute Laplace transform","code":"laplace(f)","runOnInsert":true,"nargOut":1},{"entryType":"function","ID":"ztrans","text":"Compute Z-transform","description":"Compute Z-transform","code":"ztrans(f)","runOnInsert":true,"nargOut":1},{"entryType":"separator","ID":"menuSeparator"},{"entryType":"function","ID":"ifourier","text":"Compute inverse Fourier transform","description":"Compute inverse Fourier transform","code":"ifourier(f)","runOnInsert":true,"nargOut":1},{"entryType":"function","ID":"ihtrans","text":"Compute inverse Hilbert transform","description":"Compute inverse Hilbert transform","code":"ihtrans(f)","runOnInsert":true,"nargOut":1},{"entryType":"function","ID":"ilaplace","text":"Compute inverse Laplace transform","description":"Compute inverse Laplace transform","code":"ilaplace(f)","runOnInsert":true,"nargOut":1},{"entryType":"function","ID":"iztrans","text":"Compute inverse Z-transform","description":"Compute inverse Z-transform","code":"iztrans(f)","runOnInsert":true,"nargOut":1}]},{"entryType":"menu","ID":"menuNumber","text":"Plotting functions","description":"Plotting functions, expressions, and equations","children":[{"entryType":"function","ID":"fimplicit","text":"Plot implicit equation in 2-D","description":"Plot 2-D implicit equation or function f(x,y)","code":"fimpl ...
%     </annotation>
%   </semantics>
% </math>

% %%
gradf = jacobian(f,x).' % column gradf
% Out:
% <math xmlns='http://www.w3.org/1998/Math/MathML' display='block' xmlns:mw='https://www.mathworks.com/MathML/extensions'>
%   <semantics>
%     <mtable columnalign='left' mw:template='abbreviation' mw:dataCategory='structure'>
%       <mtr>
%         <mtd>
%           <mrow mw:dataCategory='placeholder'>
%             <mrow mw:template='matrix' mw:dataCategory='structure'>
%               <mo form='prefix' mw:dataCategory='static'>(</mo>
%               <mtable>
%                 <mtr>
%                   <mtd>
%                     <mrow mw:dataCategory='placeholder'>
%                       <mrow mw:template='plus' mw:dataCategory='structure'>
%                         <mrow mw:dataCategory='placeholder'>
%                           <mo>-</mo>
%                           <mfrac mw:template='divide' mw:dataCategory='structure'>
%                             <mrow mw:dataCategory='placeholder'>
%                               <mrow mw:template='plus' mw:dataCategory='structure'>
%                                 <mrow mw:dataCategory='placeholder'>
%                                   <mrow mw:template='times' mw:dataCategory='structure'>
%                                     <mrow mw:dataCategory='placeholder'>
%                                       <mn>6</mn>
%                                       <mo form='infix' mw:dataCategory='static'>&InvisibleTimes;</mo>
%                                       <mfenced mw:dataCategory='structure-part'>
%                                         <mrow mw:template='plus' mw:dataCategory='structure'>
%                                           <mrow mw:dataCategory='placeholder'>
%                                             <mrow mw:template='times' mw:dataCategory='structure'>
%                                               <mrow mw:dataCategory='placeholder'>
%                                                 <mn>3</mn>
%                                                 <mo form='infix' mw:dataCategory='static'>&InvisibleTimes;</mo>
%                                                 <msup mw:template='power' mw:dataCategory='structure'>
%                                                   <mrow mw:dataCategory='placeholder'>
%                                                     <msub mw:varname='x1'>
%                                                       <mi>x</mi>
%                                                       <mn>1</mn>
%                                                     </msub>
%                                                   </mrow>
%                                                   <mrow mw:dataCategory='placeholder'>
%                                                     <mn>2</mn>
%                                                   </mrow>
%                                                 </msup>
%                                               </mrow>
%                                             </mrow>
%                                             <mo>-</mo>
%                                             <mn>1</mn>
%                                           </mrow>
%                                         </mrow>
%                                       </mfenced>
%                                       <mo form='infix' mw:dataCategory='static'>&InvisibleTimes;</mo>
%                                       <mfenced mw:dataCategory='structure-part'>
%                                         <mrow mw:template='plus' mw:dataCategory='structure'>
%                                           <mrow mw:dataCategory='placeholder'>
%                                             <mo>-</mo>
%                                             <msup mw:template='power' mw:dataCategory='structure'>
%                                               <mrow mw:dataCategory='placeholder'>
%                                                 <msub mw:varname='x1'>
%                                                   <mi>x</mi>
%                                                   <mn>1</mn>
%                                                 </msub>
%                                               </mrow>
%                                               <mrow mw:dataCategory='placeholder'>
%                                                 <mn>3</mn>
%                                               </mrow>
%                                             </msup>
%                                             <mo>+</mo>
%                                             <msub mw:varname='x1'>
%                                               <mi>x</mi>
%                                               <mn>1</mn>
%                                             </msub>
%                                             <mo>+</mo>
%                                             <msub mw:varname='x2'>
%                                               <mi>x</mi>
%                                               <mn>2</mn>
%                                             </msub>
%                                           </mrow>
%                                         </mrow>
%                                       </mfenced>
%                                     </mrow>
%                                   </mrow>
%                                   <mo>-</mo>
%                                   <mrow mw:template='times' mw:dataCategory='structure'>
%                                     <mrow mw:dataCategory='placeholder'>
%                                       <mn>2</mn>
%                                       <mo form='infix' mw:dataCategory='static'>&InvisibleTimes;</mo>
%                                       <msub mw:varname='x1'>
%                                         <mi>x</mi>
%                                         <mn>1</mn>
%                                       </msub>
%                                     </mrow>
%                                   </mrow>
%                                   <mo>+</mo>
%                                   <mfrac mw:template='divide' mw:dataCategory='structure'>
%                                     <mrow mw:dataCategory='placeholder'>
%                                       <mn>8</mn>
%                                     </mrow>
%                                     <mrow mw:dataCategory='placeholder'>
%                                       <mn>3</mn>
%                                     </mrow>
%                                   </mfrac>
%                                 </mrow>
%                               </mrow>
%                             </mrow>
%                             <mrow mw:dataCategory='placeholder'>
%                               <msub mw:varname='sigma1'>
%                                 <mi>&sigma;</mi>
%                                 <mn>1</mn>
%                               </msub>
%                             </mrow>
%                           </mfrac>
%                         </mrow>
%                       </mrow>
%                     </mrow>
%                   </mtd>
%                 </mtr>
%                 <mtr>
%                   <mtd>
%                     <mrow mw:dataCategory='placeholder'>
%                       <mfrac mw:template='divide' mw:dataCategory='structure'>
%                         <mrow mw:dataCategory='placeholder'>
%                           <mrow mw:template='plus' mw:dataCategory='structure'>
%                             <mrow mw:dataCategory='placeholder'>
%                               <mo>-</mo>
%                               <mrow mw:template='times' mw:dataCategory='structure'>
%                                 <mrow mw:dataCategory='placeholder'>
%                                   <mn>6</mn>
%                                   <mo form='infix' mw:dataCategory='static'>&InvisibleTimes;</mo>
%                                   <msup mw:template='power' mw:dataCategory='structure'>
%                                     <mrow mw:dataCategory='placeholder'>
%                                       <msub mw:varname='x1'>
%                                         <mi>x</mi>
%                                         <mn>1</mn>
%                                       </msub>
%                                     </mrow>
%                                     <mrow mw:dataCategory='placeholder'>
%                                       <mn>3</mn>
%                                     </mrow>
%                                   </msup>
%                                 </mrow>
%                               </mrow>
%                               <mo>+</mo>
%                               <mrow mw:template='times' mw:dataCategory='structure'>
%                                 <mrow mw:dataCategory='placeholder'>
%                                   <mn>6</mn>
%                                   <mo form='infix' mw:dataCategory='static'>&InvisibleTimes;</mo>
%                                   <msub mw:varname='x1'>
%                                     <mi>x</mi>
%                                     <mn>1</mn>
%                                   </msub>
%                                 </mrow>
%                               </mrow>
%                               <mo>+</mo>
%                               <mrow mw:template='times' mw:dataCategory='structure'>
%                                 <mrow mw:dataCategory='placeholder'>
%                                   <mn>6</mn>
%                                   <mo form='infix' mw:dataCategory='static'>&InvisibleTimes;</mo>
%                                   <msub mw:varname='x2'>
%                                     <mi>x</mi>
%                                     <mn>2</mn>
%                                   </msub>
%                                 </mrow>
%                               </mrow>
%                             </mrow>
%                           </mrow>
%                         </mrow>
%                         <mrow mw:dataCategory='placeholder'>
%                           <msub mw:varname='sigma1'>
%                             <mi>&sigma;</mi>
%                             <mn>1</mn>
%                           </msub>
%                         </mrow>
%                       </mfrac>
%                     </mrow>
%                   </mtd>
%                 </mtr>
%               </mtable>
%               <mo form='postfix' mw:dataCategory='static'>)</mo>
%             </mrow>
%           </mrow>
%         </mtd>
%       </mtr>
%       <mtr>
%         <mtd>
%           <mi> </mi>
%         </mtd>
%       </mtr>
%       <mtr>
%         <mtd>
%           <mi>where</mi>
%         </mtd>
%       </mtr>
%       <mtr>
%         <mtd>
%           <mi> </mi>
%         </mtd>
%       </mtr>
%       <mtr>
%         <mtd>
%           <mrow mw:dataCategory='placeholder'>
%             <mrow mw:template='row' mw:dataCategory='structure'>
%               <mrow mw:dataCategory='placeholder'>
%                 <mi>&MediumSpace;&MediumSpace;</mi>
%                 <mrow/>
%                 <mrow mw:template='eq' mw:dataCategory='structure'>
%                   <mrow mw:dataCategory='placeholder'>
%                     <msub mw:varname='sigma1'>
%                       <mi>&sigma;</mi>
%                       <mn>1</mn>
%                     </msub>
%                     <mo form='infix' mw:dataCategory='static'>&equals;</mo>
%                     <mrow mw:template='plus' mw:dataCategory='structure'>
%                       <mrow mw:dataCategory='placeholder'>
%                         <msup mw:template='power' mw:dataCategory='structure'>
%                           <mfenced mw:dataCategory='structure-part'>
%                             <mrow mw:dataCategory='placeholder'>
%                               <mrow mw:template='plus' mw:dataCategory='structure'>
%                                 <mrow mw:dataCategory='placeholder'>
%                                   <msub mw:varname='x1'>
%                                     <mi>x</mi>
%                                     <mn>1</mn>
%                                   </msub>
%                                   <mo>-</mo>
%                                   <mfrac mw:template='divide' mw:dataCategory='structure'>
%                                     <mrow mw:dataCategory='placeholder'>
%                                       <mn>4</mn>
%                                     </mrow>
%                                     <mrow mw:dataCategory='placeholder'>
%                                       <mn>3</mn>
%                                     </mrow>
%                                   </mfrac>
%                                 </mrow>
%                               </mrow>
%                             </mrow>
%                           </mfenced>
%                           <mrow mw:dataCategory='placeholder'>
%                             <mn>2</mn>
%                           </mrow>
%                         </msup>
%                         <mo>+</mo>
%                         <mrow mw:template='times' mw:dataCategory='structure'>
%                           <mrow mw:dataCategory='placeholder'>
%                             <mn>3</mn>
%                             <mo form='infix' mw:dataCategory='static'>&InvisibleTimes;</mo>
%                             <msup mw:template='power' mw:dataCategory='structure'>
%                               <mfenced mw:dataCategory='structure-part'>
%                                 <mrow mw:dataCategory='placeholder'>
%                                   <mrow mw:template='plus' mw:dataCategory='structure'>
%                                     <mrow mw:dataCategory='placeholder'>
%                                       <mo>-</mo>
%                                       <msup mw:template='power' mw:dataCategory='structure'>
%                                         <mrow mw:dataCategory='placeholder'>
%                                           <msub mw:varname='x1'>
%                                             <mi>x</mi>
%                                             <mn>1</mn>
%                                           </msub>
%                                         </mrow>
%                                         <mrow mw:dataCategory='placeholder'>
%                                           <mn>3</mn>
%                                         </mrow>
%                                       </msup>
%                                       <mo>+</mo>
%                                       <msub mw:varname='x1'>
%                                         <mi>x</mi>
%                                         <mn>1</mn>
%                                       </msub>
%                                       <mo>+</mo>
%                                       <msub mw:varname='x2'>
%                                         <mi>x</mi>
%                                         <mn>2</mn>
%                                       </msub>
%                                     </mrow>
%                                   </mrow>
%                                 </mrow>
%                               </mfenced>
%                               <mrow mw:dataCategory='placeholder'>
%                                 <mn>2</mn>
%                               </mrow>
%                             </msup>
%                           </mrow>
%                         </mrow>
%                         <mo>+</mo>
%                         <mn>1</mn>
%                       </mrow>
%                     </mrow>
%                   </mrow>
%                 </mrow>
%               </mrow>
%             </mrow>
%           </mrow>
%         </mtd>
%       </mtr>
%     </mtable>
%     <annotation encoding='OutputVersion'>
%       1.0
%     </annotation>
%     <annotation encoding='Suggestions'>
%       [{"entryType":"function","ID":"vpa","text":"Approximate numerically","description":"Approximate numerically using variable precision floating point arithmetic","code":"vpa(gradf)","runOnInsert":true,"nargOut":1},{"entryType":"function","ID":"jacobian","text":"Compute Jacobian matrix of vector","description":"Compute Jacobian matrix of vector","code":"jacobian(gradf)","runOnInsert":true,"nargOut":1},{"entryType":"menu","ID":"menuCalculus","text":"Applying calculus functions","description":"Applying calculus functions","children":[{"entryType":"function","ID":"diff","text":"Differentiate function","description":"Compute derivative of function with respect to specific variable","code":"diff(gradf,x1)","runOnInsert":true,"nargOut":1},{"entryType":"function","ID":"int","text":"Integrate function","description":"Compute indefinite integral of function with respect to specific variable","code":"int(gradf,x1)","runOnInsert":true,"nargOut":1}]},{"entryType":"menu","ID":"menuTransform","text":"Computing integral transforms","description":"Computing integral transforms","children":[{"entryType":"function","ID":"fourier","text":"Compute Fourier transform","description":"Compute Fourier transform","code":"fourier(gradf)","runOnInsert":true,"nargOut":1},{"entryType":"function","ID":"htrans","text":"Compute Hilbert transform","description":"Compute Hilbert transform","code":"htrans(gradf)","runOnInsert":true,"nargOut":1},{"entryType":"function","ID":"laplace","text":"Compute Laplace transform","description":"Compute Laplace transform","code":"laplace(gradf)","runOnInsert":true,"nargOut":1},{"entryType":"function","ID":"ztrans","text":"Compute Z-transform","description":"Compute Z-transform","code":"ztrans(gradf)","runOnInsert":true,"nargOut":1},{"entryType":"separator","ID":"menuSeparator"},{"entryType":"function","ID":"ifourier","text":"Compute inverse Fourier transform","description":"Compute inverse Fourier transform","code":"ifourier(gradf)","runOnInsert":true,"nargOut":1},{"entryType":"function","ID":"ihtrans","text":"Compute inverse Hilbert transform","description":"Compute inverse Hilbert transform","code":"ihtrans(gradf)","runOnInsert":true,"nargOut":1},{"entryType":"function","ID":"ilaplace","text":"Compute inverse Laplace transform","description":"Compute inverse Laplace transform","code":"ilaplace(gradf)","runOnInsert":true,"nargOut":1},{"entryType":"function","ID":"iztrans","text":"Compute inverse Z-transform","description":"Compute inverse Z-transform","code":"iztrans(gradf)","runOnInsert":true,"nargOut":1}]},{"entryType":"menu","ID":"menuNumber","text":"Plotting functions","description":"Plotting functions, expressions, and equations","children":[{"entryType":"function","ID":"fimplicit","text":"Plot implicit equation in 2-D","description":"Plot 2-D implicit equation or function f(x,y)","code":"fimplicit(gradf)","runOnInsert":true,"nargOut":0},{"entryType":"function","ID":"fimplicit3","text":"Plot implicit equation in 3-D","description":"Plot 3-D implicit equation or function f(x,y,z)","code":"fimplicit3(gradf)","runOnInsert":true,"nargOut":0},{"entryType":"function","ID":"fmesh","text":"Plot mesh in 3-D","description":"Plot 3-D mesh from function f(x,y) or expression","code":"fmesh(gradf)","runOnInsert":true,"nargOut":0},{"entryType":"function","ID":"fsurf","text":"Plot surface in 3-D","description":"Plot 3-D surface from function f(x,y) or expression","code":"fsurf(gradf)","runOnInsert":true,"nargOut":0}]},{"entryType":"menu","ID":"menuRewriting","text":"Rewriting and simplifying expressions","description":"Rewriting and simplifying symbolic expressions","children":[{"entryType":"task","ID":"taskSimplifyCombine","text":"Combine expression","description":"Combine terms of the same algebraic structure","pseudoCode":"The Simplify Symbolic Expression task will be inserted here with Method set to 'Combine'","appConfig":{"appIdentifier":"matlab.internal.symbolic.task.Simplify","runOnInsert":true},"appState":{"Expression":"grad ...
%     </annotation>
%   </semantics>
% </math>

% %%
hessf = jacobian(gradf,x)
% Out:
% <math xmlns='http://www.w3.org/1998/Math/MathML' display='block' xmlns:mw='https://www.mathworks.com/MathML/extensions'>
%   <semantics>
%     <mtable columnalign='left' mw:template='abbreviation' mw:dataCategory='structure'>
%       <mtr>
%         <mtd>
%           <mrow mw:dataCategory='placeholder'>
%             <mrow mw:template='matrix' mw:dataCategory='structure'>
%               <mo form='prefix' mw:dataCategory='static'>(</mo>
%               <mtable>
%                 <mtr>
%                   <mtd>
%                     <mrow mw:dataCategory='placeholder'>
%                       <mrow mw:template='plus' mw:dataCategory='structure'>
%                         <mrow mw:dataCategory='placeholder'>
%                           <mfrac mw:template='divide' mw:dataCategory='structure'>
%                             <mrow mw:dataCategory='placeholder'>
%                               <mrow mw:template='plus' mw:dataCategory='structure'>
%                                 <mrow mw:dataCategory='placeholder'>
%                                   <mrow mw:template='times' mw:dataCategory='structure'>
%                                     <mrow mw:dataCategory='placeholder'>
%                                       <mn>6</mn>
%                                       <mo form='infix' mw:dataCategory='static'>&InvisibleTimes;</mo>
%                                       <msup mw:template='power' mw:dataCategory='structure'>
%                                         <mfenced mw:dataCategory='structure-part'>
%                                           <mrow mw:dataCategory='placeholder'>
%                                             <mrow mw:template='plus' mw:dataCategory='structure'>
%                                               <mrow mw:dataCategory='placeholder'>
%                                                 <mrow mw:template='times' mw:dataCategory='structure'>
%                                                   <mrow mw:dataCategory='placeholder'>
%                                                     <mn>3</mn>
%                                                     <mo form='infix' mw:dataCategory='static'>&InvisibleTimes;</mo>
%                                                     <msup mw:template='power' mw:dataCategory='structure'>
%                                                       <mrow mw:dataCategory='placeholder'>
%                                                         <msub mw:varname='x1'>
%                                                           <mi>x</mi>
%                                                           <mn>1</mn>
%                                                         </msub>
%                                                       </mrow>
%                                                       <mrow mw:dataCategory='placeholder'>
%                                                         <mn>2</mn>
%                                                       </mrow>
%                                                     </msup>
%                                                   </mrow>
%                                                 </mrow>
%                                                 <mo>-</mo>
%                                                 <mn>1</mn>
%                                               </mrow>
%                                             </mrow>
%                                           </mrow>
%                                         </mfenced>
%                                         <mrow mw:dataCategory='placeholder'>
%                                           <mn>2</mn>
%                                         </mrow>
%                                       </msup>
%                                     </mrow>
%                                   </mrow>
%                                   <mo>-</mo>
%                                   <mrow mw:template='times' mw:dataCategory='structure'>
%                                     <mrow mw:dataCategory='placeholder'>
%                                       <mn>36</mn>
%                                       <mo form='infix' mw:dataCategory='static'>&InvisibleTimes;</mo>
%                                       <msub mw:varname='x1'>
%                                         <mi>x</mi>
%                                         <mn>1</mn>
%                                       </msub>
%                                       <mo form='infix' mw:dataCategory='static'>&InvisibleTimes;</mo>
%                                       <mfenced mw:dataCategory='structure-part'>
%                                         <mrow mw:template='plus' mw:dataCategory='structure'>
%                                           <mrow mw:dataCategory='placeholder'>
%                                             <mo>-</mo>
%                                             <msup mw:template='power' mw:dataCategory='structure'>
%                                               <mrow mw:dataCategory='placeholder'>
%                                                 <msub mw:varname='x1'>
%                                                   <mi>x</mi>
%                                                   <mn>1</mn>
%                                                 </msub>
%                                               </mrow>
%                                               <mrow mw:dataCategory='placeholder'>
%                                                 <mn>3</mn>
%                                               </mrow>
%                                             </msup>
%                                             <mo>+</mo>
%                                             <msub mw:varname='x1'>
%                                               <mi>x</mi>
%                                               <mn>1</mn>
%                                             </msub>
%                                             <mo>+</mo>
%                                             <msub mw:varname='x2'>
%                                               <mi>x</mi>
%                                               <mn>2</mn>
%                                             </msub>
%                                           </mrow>
%                                         </mrow>
%                                       </mfenced>
%                                     </mrow>
%                                   </mrow>
%                                   <mo>+</mo>
%                                   <mn>2</mn>
%                                 </mrow>
%                               </mrow>
%                             </mrow>
%                             <mrow mw:dataCategory='placeholder'>
%                               <msub mw:varname='sigma2'>
%                                 <mi>&sigma;</mi>
%                                 <mn>2</mn>
%                               </msub>
%                             </mrow>
%                           </mfrac>
%                           <mo>-</mo>
%                           <mfrac mw:template='divide' mw:dataCategory='structure'>
%                             <mrow mw:dataCategory='placeholder'>
%                               <msup mw:template='power' mw:dataCategory='structure'>
%                                 <mrow mw:dataCategory='placeholder'>
%                                   <msub mw:varname='sigma3'>
%                                     <mi>&sigma;</mi>
%                                     <mn>3</mn>
%                                   </msub>
%                                 </mrow>
%                                 <mrow mw:dataCategory='placeholder'>
%                                   <mn>2</mn>
%                                 </mrow>
%                               </msup>
%                             </mrow>
%                             <mrow mw:dataCategory='placeholder'>
%                               <msup mw:template='power' mw:dataCategory='structure'>
%                                 <mrow mw:dataCategory='placeholder'>
%                                   <msub mw:varname='sigma2'>
%                                     <mi>&sigma;</mi>
%                                     <mn>2</mn>
%                                   </msub>
%                                 </mrow>
%                                 <mrow mw:dataCategory='placeholder'>
%                                   <mn>2</mn>
%                                 </mrow>
%                               </msup>
%                             </mrow>
%                           </mfrac>
%                         </mrow>
%                       </mrow>
%                     </mrow>
%                   </mtd>
%                   <mtd>
%                     <msub mw:varname='sigma1'>
%                       <mi>&sigma;</mi>
%                       <mn>1</mn>
%                     </msub>
%                   </mtd>
%                 </mtr>
%                 <mtr>
%                   <mtd>
%                     <msub mw:varname='sigma1'>
%                       <mi>&sigma;</mi>
%                       <mn>1</mn>
%                     </msub>
%                   </mtd>
%                   <mtd>
%                     <mrow mw:dataCategory='placeholder'>
%                       <mrow mw:template='plus' mw:dataCategory='structure'>
%                         <mrow mw:dataCategory='placeholder'>
%                           <mfrac mw:template='divide' mw:dataCategory='structure'>
%                             <mrow mw:dataCategory='placeholder'>
%                               <mn>6</mn>
%                             </mrow>
%                             <mrow mw:dataCategory='placeholder'>
%                               <msub mw:varname='sigma2'>
%                                 <mi>&sigma;</mi>
%                                 <mn>2</mn>
%                               </msub>
%                             </mrow>
%                           </mfrac>
%                           <mo>-</mo>
%                           <mfrac mw:template='divide' mw:dataCategory='structure'>
%                             <mrow mw:dataCategory='placeholder'>
%                               <msup mw:template='power' mw:dataCategory='structure'>
%                                 <mfenced mw:dataCategory='structure-part'>
%                                   <mrow mw:dataCategory='placeholder'>
%                                     <mrow mw:template='plus' mw:dataCategory='structure'>
%                                       <mrow mw:dataCategory='placeholder'>
%                                         <mo>-</mo>
%                                         <mrow mw:template='times' mw:dataCategory='structure'>
%                                           <mrow mw:dataCategory='placeholder'>
%                                             <mn>6</mn>
%                                             <mo form='infix' mw:dataCategory='static'>&InvisibleTimes;</mo>
%                                             <msup mw:template='power' mw:dataCategory='structure'>
%                                               <mrow mw:dataCategory='placeholder'>
%                                                 <msub mw:varname='x1'>
%                                                   <mi>x</mi>
%                                                   <mn>1</mn>
%                                                 </msub>
%                                               </mrow>
%                                               <mrow mw:dataCategory='placeholder'>
%                                                 <mn>3</mn>
%                                               </mrow>
%                                             </msup>
%                                           </mrow>
%                                         </mrow>
%                                         <mo>+</mo>
%                                         <mrow mw:template='times' mw:dataCategory='structure'>
%                                           <mrow mw:dataCategory='placeholder'>
%                                             <mn>6</mn>
%                                             <mo form='infix' mw:dataCategory='static'>&InvisibleTimes;</mo>
%                                             <msub mw:varname='x1'>
%                                               <mi>x</mi>
%                                               <mn>1</mn>
%                                             </msub>
%                                           </mrow>
%                                         </mrow>
%                                         <mo>+</mo>
%                                         <mrow mw:template='times' mw:dataCategory='structure'>
%                                           <mrow mw:dataCategory='placeholder'>
%                                             <mn>6</mn>
%                                             <mo form='infix' mw:dataCategory='static'>&InvisibleTimes;</mo>
%                                             <msub mw:varname='x2'>
%                                               <mi>x</mi>
%                                               <mn>2</mn>
%                                             </msub>
%                                           </mrow>
%                                         </mrow>
%                                       </mrow>
%                                     </mrow>
%                                   </mrow>
%                                 </mfenced>
%                                 <mrow mw:dataCategory='placeholder'>
%                                   <mn>2</mn>
%                                 </mrow>
%                               </msup>
%                             </mrow>
%                             <mrow mw:dataCategory='placeholder'>
%                               <msup mw:template='power' mw:dataCategory='structure'>
%                                 <mrow mw:dataCategory='placeholder'>
%                                   <msub mw:varname='sigma2'>
%                                     <mi>&sigma;</mi>
%                                     <mn>2</mn>
%                                   </msub>
%                                 </mrow>
%                                 <mrow mw:dataCategory='placeholder'>
%                                   <mn>2</mn>
%                                 </mrow>
%                               </msup>
%                             </mrow>
%                           </mfrac>
%                         </mrow>
%                       </mrow>
%                     </mrow>
%                   </mtd>
%                 </mtr>
%               </mtable>
%               <mo form='postfix' mw:dataCategory='static'>)</mo>
%             </mrow>
%           </mrow>
%         </mtd>
%       </mtr>
%       <mtr>
%         <mtd>
%           <mi> </mi>
%         </mtd>
%       </mtr>
%       <mtr>
%         <mtd>
%           <mi>where</mi>
%         </mtd>
%       </mtr>
%       <mtr>
%         <mtd>
%           <mi> </mi>
%         </mtd>
%       </mtr>
%       <mtr>
%         <mtd>
%           <mrow mw:dataCategory='placeholder'>
%             <mrow mw:template='row' mw:dataCategory='structure'>
%               <mrow mw:dataCategory='placeholder'>
%                 <mi>&MediumSpace;&MediumSpace;</mi>
%                 <mrow/>
%                 <mrow mw:template='eq' mw:dataCategory='structure'>
%                   <mrow mw:dataCategory='placeholder'>
%                     <msub mw:varname='sigma1'>
%                       <mi>&sigma;</mi>
%                       <mn>1</mn>
%                     </msub>
%                     <mo form='infix' mw:dataCategory='static'>&equals;</mo>
%                     <mrow mw:template='plus' mw:dataCategory='structure'>
%                       <mrow mw:dataCategory='placeholder'>
%                         <mfrac mw:template='divide' mw:dataCategory='structure'>
%                           <mrow mw:dataCategory='placeholder'>
%                             <mrow mw:template='times' mw:dataCategory='structure'>
%                               <mrow mw:dataCategory='placeholder'>
%                                 <mfenced mw:dataCategory='structure-part'>
%                                   <mrow mw:template='plus' mw:dataCategory='structure'>
%                                     <mrow mw:dataCategory='placeholder'>
%                                       <mo>-</mo>
%                                       <mrow mw:template='times' mw:dataCategory='structure'>
%                                         <mrow mw:dataCategory='placeholder'>
%                                           <mn>6</mn>
%                                           <mo form='infix' mw:dataCategory='static'>&InvisibleTimes;</mo>
%                                           <msup mw:template='power' mw:dataCategory='structure'>
%                                             <mrow mw:dataCategory='placeholder'>
%                                               <msub mw:varname='x1'>
%                                                 <mi>x</mi>
%                                                 <mn>1</mn>
%                                               </msub>
%                                             </mrow>
%                                             <mrow mw:dataCategory='placeholder'>
%                                               <mn>3</mn>
%                                             </mrow>
%                                           </msup>
%                                         </mrow>
%                                       </mrow>
%                                       <mo>+</mo>
%                                       <mrow mw:template='times' mw:dataCategory='structure'>
%                                         <mrow mw:dataCategory='placeholder'>
%                                           <mn>6</mn>
%                                           <mo form='infix' mw:dataCategory='static'>&InvisibleTimes;</mo>
%                                           <msub mw:varname='x1'>
%                                             <mi>x</mi>
%                                             <mn>1</mn>
%                                           </msub>
%                                         </mrow>
%                                       </mrow>
%                                       <mo>+</mo>
%                                       <mrow mw:template='times' mw:dataCategory='structure'>
%                                         <mrow mw:dataCategory='placeholder'>
%                                           <mn>6</mn>
%                                           <mo form='infix' mw:dataCategory='static'>&InvisibleTimes;</mo>
%                                           <msub mw:varname='x2'>
%                                             <mi>x</mi>
%                                             <mn>2</mn>
%                                           </msub>
%                                         </mrow>
%                                       </mrow>
%                                     </mrow>
%                                   </mrow>
%                                 </mfenced>
%                                 <mo form='infix' mw:dataCategory='static'>&InvisibleTimes;</mo>
%                                 <msub mw:varname='sigma3'>
%                                   <mi>&sigma;</mi>
%                                   <mn>3</mn>
%                                 </msub>
%                               </mrow>
%                             </mrow>
%                           </mrow>
%                           <mrow mw:dataCategory='placeholder'>
%                             <msup mw:template='power' mw:dataCategory='structure'>
%                               <mrow mw:dataCategory='placeholder'>
%                                 <msub mw:varname='sigma2'>
%                                   <mi>&sigma;</mi>
%                                   <mn>2</mn>
%                                 </msub>
%                               </mrow>
%                               <mrow mw:dataCategory='placeholder'>
%                                 <mn>2</mn>
%                               </mrow>
%                             </msup>
%                           </mrow>
%                         </mfrac>
%                         <mo>-</mo>
%                         <mfrac mw:template='divide' mw:dataCategory='structure'>
%                           <mrow mw:dataCategory='placeholder'>
%                             <mrow mw:template='plus' mw:dataCategory='structure'>
%                               <mrow mw:dataCategory='placeholder'>
%                                 <mrow mw:template='times' mw:dataCategory='structure'>
%                                   <mrow mw:dataCategory='placeholder'>
%                                     <mn>18</mn>
%                                     <mo form='infix' mw:dataCategory='static'>&InvisibleTimes;</mo>
%                                     <msup mw:template='power' mw:dataCategory='structure'>
%                                       <mrow mw:dataCategory='placeholder'>
%                                         <msub mw:varname='x1'>
%                                           <mi>x</mi>
%                                           <mn>1</mn>
%                                         </msub>
%                                       </mrow>
%                                       <mrow mw:dataCategory='placeholder'>
%                                         <mn>2</mn>
%                                       </mrow>
%                                     </msup>
%                                   </mrow>
%                                 </mrow>
%                                 <mo>-</mo>
%                                 <mn>6</mn>
%                               </mrow>
%                             </mrow>
%                           </mrow>
%                           <mrow mw:dataCategory='placeholder'>
%                             <msub mw:varname='sigma2'>
%                               <mi>&sigma;</mi>
%                               <mn>2</mn>
%                             </msub>
%                           </mrow>
%                         </mfrac>
%                       </mrow>
%                     </mrow>
%                   </mrow>
%                 </mrow>
%               </mrow>
%             </mrow>
%           </mrow>
%         </mtd>
%       </mtr>
%       <mtr>
%         <mtd>
%           <mi> </mi>
%         </mtd>
%       </mtr>
%       <mtr>
%         <mtd>
%           <mrow mw:dataCategory='placeholder'>
%             <mrow mw:template='row' mw:dataCategory='structure'>
%               <mrow mw:dataCategory='placeholder'>
%                 <mi>&MediumSpace;&MediumSpace;</mi>
%                 <mrow/>
%                 <mrow mw:template='eq' mw:dataCategory='structure'>
%                   <mrow mw:dataCategory='placeholder'>
%                     <msub mw:varname='sigma2'>
%                       <mi>&sigma;</mi>
%                       <mn>2</mn>
%                     </msub>
%                     <mo form='infix' mw:dataCategory='static'>&equals;</mo>
%                     <mrow mw:template='plus' mw:dataCategory='structure'>
%                       <mrow mw:dataCategory='placeholder'>
%                         <msup mw:template='power' mw:dataCategory='structure'>
%                           <mfenced mw:dataCategory='structure-part'>
%                             <mrow mw:dataCategory='placeholder'>
%                               <mrow mw:template='plus' mw:dataCategory='structure'>
%                                 <mrow mw:dataCategory='placeholder'>
%                                   <msub mw:varname='x1'>
%                                     <mi>x</mi>
%                                     <mn>1</mn>
%                                   </msub>
%                                   <mo>-</mo>
%                                   <mfrac mw:template='divide' mw:dataCategory='structure'>
%                                     <mrow mw:dataCategory='placeholder'>
%                                       <mn>4</mn>
%                                     </mrow>
%                                     <mrow mw:dataCategory='placeholder'>
%                                       <mn>3</mn>
%                                     </mrow>
%                                   </mfrac>
%                                 </mrow>
%                               </mrow>
%                             </mrow>
%                           </mfenced>
%                           <mrow mw:dataCategory='placeholder'>
%                             <mn>2</mn>
%                           </mrow>
%                         </msup>
%                         <mo>+</mo>
%                         <mrow mw:template='times' mw:dataCategory='structure'>
%                           <mrow mw:dataCategory='placeholder'>
%                             <mn>3</mn>
%                             <mo form='infix' mw:dataCategory='static'>&InvisibleTimes;</mo>
%                             <msup mw:template='power' mw:dataCategory='structure'>
%                               <mfenced mw:dataCategory='structure-part'>
%                                 <mrow mw:dataCategory='placeholder'>
%                                   <mrow mw:template='plus' mw:dataCategory='structure'>
%                                     <mrow mw:dataCategory='placeholder'>
%                                       <mo>-</mo>
%                                       <msup mw:template='power' mw:dataCategory='structure'>
%                                         <mrow mw:dataCategory='placeholder'>
%                                           <msub mw:varname='x1'>
%                                             <mi>x</mi>
%                                             <mn>1</mn>
%                                           </msub>
%                                         </mrow>
%                                         <mrow mw:dataCategory='placeholder'>
%                                           <mn>3</mn>
%                                         </mrow>
%                                       </msup>
%                                       <mo>+</mo>
%                                       <msub mw:varname='x1'>
%                                         <mi>x</mi>
%                                         <mn>1</mn>
%                                       </msub>
%                                       <mo>+</mo>
%                                       <msub mw:varname='x2'>
%                                         <mi>x</mi>
%                                         <mn>2</mn>
%                                       </msub>
%                                     </mrow>
%                                   </mrow>
%                                 </mrow>
%                               </mfenced>
%                               <mrow mw:dataCategory='placeholder'>
%                                 <mn>2</mn>
%                               </mrow>
%                             </msup>
%                           </mrow>
%                         </mrow>
%                         <mo>+</mo>
%                         <mn>1</mn>
%                       </mrow>
%                     </mrow>
%                   </mrow>
%                 </mrow>
%               </mrow>
%             </mrow>
%           </mrow>
%         </mtd>
%       </mtr>
%       <mtr>
%         <mtd>
%           <mi> </mi>
%         </mtd>
%       </mtr>
%       <mtr>
%         <mtd>
%           <mrow mw:dataCategory='placeholder'>
%             <mrow mw:template='row' mw:dataCategory='structure'>
%               <mrow mw:dataCategory='placeholder'>
%                 <mi>&MediumSpace;&MediumSpace;</mi>
%                 <mrow/>
%                 <mrow mw:template='eq' mw:dataCategory='structure'>
%                   <mrow mw:dataCategory='placeholder'>
%                     <msub mw:varname='sigma3'>
%                       <mi>&sigma;</mi>
%                       <mn>3</mn>
%                     </msub>
%                     <mo form='infix' mw:dataCategory='static'>&equals;</mo>
%                     <mrow mw:template='plus' mw:dataCategory='structure'>
%                       <mrow mw:dataCategory='placeholder'>
%                         <mrow mw:template='times' mw:dataCategory='structure'>
%                           <mrow mw:dataCategory='placeholder'>
%                             <mn>6</mn>
%                             <mo form='infix' mw:dataCategory='static'>&InvisibleTimes;</mo>
%                             <mfenced mw:dataCategory='structure-part'>
%                               <mrow mw:template='plus' mw:dataCategory='structure'>
%                                 <mrow mw:dataCategory='placeholder'>
%                                   <mrow mw:template='times' mw:dataCategory='structure'>
%                                     <mrow mw:dataCategory='placeholder'>
%                                       <mn>3</mn>
%                                       <mo form='infix' mw:dataCategory='static'>&InvisibleTimes;</mo>
%                                       <msup mw:template='power' mw:dataCategory='structure'>
%                                         <mrow mw:dataCategory='placeholder'>
%                                           <msub mw:varname='x1'>
%                                             <mi>x</mi>
%                                             <mn>1</mn>
%                                           </msub>
%                                         </mrow>
%                                         <mrow mw:dataCategory='placeholder'>
%                                           <mn>2</mn>
%                                         </mrow>
%                                       </msup>
%                                     </mrow>
%                                   </mrow>
%                                   <mo>-</mo>
%                                   <mn>1</mn>
%                                 </mrow>
%                               </mrow>
%                             </mfenced>
%                             <mo form='infix' mw:dataCategory='static'>&InvisibleTimes;</mo>
%                             <mfenced mw:dataCategory='structure-part'>
%                               <mrow mw:template='plus' mw:dataCategory='structure'>
%                                 <mrow mw:dataCategory='placeholder'>
%                                   <mo>-</mo>
%                                   <msup mw:template='power' mw:dataCategory='structure'>
%                                     <mrow mw:dataCategory='placeholder'>
%                                       <msub mw:varname='x1'>
%                                         <mi>x</mi>
%                                         <mn>1</mn>
%                                       </msub>
%                                     </mrow>
%                                     <mrow mw:dataCategory='placeholder'>
%                                       <mn>3</mn>
%                                     </mrow>
%                                   </msup>
%                                   <mo>+</mo>
%                                   <msub mw:varname='x1'>
%                                     <mi>x</mi>
%                                     <mn>1</mn>
%                                   </msub>
%                                   <mo>+</mo>
%                                   <msub mw:varname='x2'>
%                                     <mi>x</mi>
%                                     <mn>2</mn>
%                                   </msub>
%                                 </mrow>
%                               </mrow>
%                             </mfenced>
%                           </mrow>
%                         </mrow>
%                         <mo>-</mo>
%                         <mrow mw:template='times' mw:dataCategory='structure'>
%                           <mrow mw:dataCategory='placeholder'>
%                             <mn>2</mn>
%                             <mo form='infix' mw:dataCategory='static'>&InvisibleTimes;</mo>
%                             <msub mw:varname='x1'>
%                               <mi>x</mi>
%                               <mn>1</mn>
%                             </msub>
%                           </mrow>
%                         </mrow>
%                         <mo>+</mo>
%                         <mfrac mw:template='divide' mw:dataCategory='structure'>
%                           <mrow mw:dataCategory='placeholder'>
%                             <mn>8</mn>
%                           </mrow>
%                           <mrow mw:dataCategory='placeholder'>
%                             <mn>3</mn>
%                           </mrow>
%                         </mfrac>
%                       </mrow>
%                     </mrow>
%                   </mrow>
%                 </mrow>
%               </mrow>
%             </mrow>
%           </mrow>
%         </mtd>
%       </mtr>
%     </mtable>
%     <annotation encoding='OutputVersion'>
%       1.0
%     </annotation>
%     <annotation encoding='Suggestions'>
%       [{"entryType":"function","ID":"vpa","text":"Approximate numerically","description":"Approximate numerically using variable precision floating point arithmetic","code":"vpa(hessf)","runOnInsert":true,"nargOut":1},{"entryType":"function","ID":"subs","text":"Substitute variables","description":"Substitute variables for values in expression or matrix: replace '0's and run code manually","code":"subs(hessf,[x1,x2],[0,0])","runOnInsert":false,"nargOut":1},{"entryType":"menu","ID":"menuCalculus","text":"Applying calculus functions","description":"Applying calculus functions","children":[{"entryType":"function","ID":"diff","text":"Differentiate function","description":"Compute derivative of function with respect to specific variable","code":"diff(hessf,x1)","runOnInsert":true,"nargOut":1},{"entryType":"function","ID":"int","text":"Integrate function","description":"Compute indefinite integral of function with respect to specific variable","code":"int(hessf,x1)","runOnInsert":true,"nargOut":1}]},{"entryType":"menu","ID":"menuMatrix","text":"Applying matrix functions","description":"Operating on matrices and vectors","children":[{"entryType":"function","ID":"det","text":"Compute determinant","description":"Compute determinant","code":"det(hessf)","runOnInsert":true,"nargOut":1},{"entryType":"function","ID":"inv","text":"Invert matrix","description":"Invert matrix","code":"inv(hessf)","runOnInsert":true,"nargOut":1}]},{"entryType":"menu","ID":"menuTransform","text":"Computing integral transforms","description":"Computing integral transforms","children":[{"entryType":"function","ID":"fourier","text":"Compute Fourier transform","description":"Compute Fourier transform","code":"fourier(hessf)","runOnInsert":true,"nargOut":1},{"entryType":"function","ID":"htrans","text":"Compute Hilbert transform","description":"Compute Hilbert transform","code":"htrans(hessf)","runOnInsert":true,"nargOut":1},{"entryType":"function","ID":"laplace","text":"Compute Laplace transform","description":"Compute Laplace transform","code":"laplace(hessf)","runOnInsert":true,"nargOut":1},{"entryType":"function","ID":"ztrans","text":"Compute Z-transform","description":"Compute Z-transform","code":"ztrans(hessf)","runOnInsert":true,"nargOut":1},{"entryType":"separator","ID":"menuSeparator"},{"entryType":"function","ID":"ifourier","text":"Compute inverse Fourier transform","description":"Compute inverse Fourier transform","code":"ifourier(hessf)","runOnInsert":true,"nargOut":1},{"entryType":"function","ID":"ihtrans","text":"Compute inverse Hilbert transform","description":"Compute inverse Hilbert transform","code":"ihtrans(hessf)","runOnInsert":true,"nargOut":1},{"entryType":"function","ID":"ilaplace","text":"Compute inverse Laplace transform","description":"Compute inverse Laplace transform","code":"ilaplace(hessf)","runOnInsert":true,"nargOut":1},{"entryType":"function","ID":"iztrans","text":"Compute inverse Z-transform","description":"Compute inverse Z-transform","code":"iztrans(hessf)","runOnInsert":true,"nargOut":1}]},{"entryType":"menu","ID":"menuRewriting","text":"Rewriting and simplifying expressions","description":"Rewriting and simplifying symbolic expressions","children":[{"entryType":"task","ID":"taskSimplifyCombine","text":"Combine expression","description":"Combine terms of the same algebraic structure","pseudoCode":"The Simplify Symbolic Expression task will be inserted here with Method set to 'Combine'","appConfig":{"appIdentifier":"matlab.internal.symbolic.task.Simplify","runOnInsert":true},"appState":{"Expression":"hessf","DisplayExpression":false,"Method":"combine"}},{"entryType":"task","ID":"taskSimplifyExpand","text":"Expand expression","description":"Write each element of expression as product of its factors","pseudoCode":"The Simplify Symbolic Expression task will be inserted here with Method set to 'Expand'","appConfig":{"appIdentifier":"matlab.internal.symbolic.task.Simplify","runOnInsert":true},"appState":{"Expression":"hessf","DisplayExpr ...
%     </annotation>
%   </semantics>
% </math>
